# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 67
#      64 plt.tight_layout(rect=[0, 0, 1, 0.96])
#      66 # Save the figure to a temporary file
# ---> 67 filename = f"generation_{generation:03d}.png"
#      68 plt.savefig(filename)
#      69 plt.close(fig)  # Close the figure to free up memory
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
plot-piecewi
